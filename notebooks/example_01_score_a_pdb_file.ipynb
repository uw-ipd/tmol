# %% [markdown]
# This notebook shows a very quick example of creating a PoseStack in from a file and scoring it

# %%
# !pip install git+https://github.com/uw-ipd/tmol.git@aleaverfay/notebooks1
# !wget https://files.ipd.uw.edu/pub/foldit/1ubq.pdb

# %%
import tmol

# %%
pose_stack = tmol.pose_stack_from_pdb("1ubq.pdb")
